# %% [markdown]
# # YoloV5 Training at GPU -- Applying Gaussian Filter at Ignored Areas
#
# Treinamento de uma rede YOLOv5-L nos dados do UAVDT Dataset. As imagens com zona de "ignore" são tratadas; nesses boxes, é aplicado um filtro gaussiano para "borrar" a imagem de forma a não deixar nenhum contorno aparente.
#
# Autor: Yuri Gonçalves Ribeiro
#
# Data: 08 de Outubro de 2020
#
# Exemplo de Execução:
#
# ```bash
# conda activate yv5; experimento="YOLOv5_UAVDT_1_TRAIN"; outputFileName=$(date "+"$experimento"_ipynb_%d_%B_%Y_%Hh_%Mm_%Ss"); echo "Salvando log de execucao em: $outputFileName.txt"; nohup jupyter nbconvert --to notebook --execute --allow-errors --output "./logs/$outputFileName" --ExecutePreprocessor.timeout=-1 --Application.log_level=10 $experimento.ipynb &> "./logs/$outputFileName.txt" &
# ```
#
# Os resultados são salvos na pasta do Dropbox especificada abaixo.

# %% [markdown]
# # Etiqueta do Experimento (Yolov5 Commit Hash, Conda Env, Informações da Máquina)

# %% [markdown]
# ## Commit Hash da Rede YoloV5 utilizada neste experimento e pacotes instalados no conda environment

# %%
# %%script bash
# echo "Hash key do commit YoloV5 que esta em uso:"
# cd ../../Submodules/yolov5
# echo $( git rev-parse --verify HEAD)
# echo
# echo "Verificar localizacao do python sendo executado:"
# which python
# echo
# echo "Conda Environment Utilizado: "
# conda env export
# Out:
# Hash key do commit YoloV5 que esta em uso:
# b42e8a531b8eb12b2f71c00ddc4dea187633f7c7
#
# Verificar localizacao do python sendo executado:
# /home/yuri/anaconda3/envs/yv5/bin/python
#
# Conda Environment Utilizado:
# name: yv5
# channels:
#   - conda-forge
#   - defaults
# dependencies:
#   - _libgcc_mutex=0.1=main
#   - argon2-cffi=20.1.0=py38h1e0a361_1
#   - attrs=19.3.0=py_0
#   - backcall=0.2.0=pyh9f0ad1d_0
#   - backports=1.0=py_2
#   - backports.functools_lru_cache=1.6.1=py_0
#   - bleach=3.1.5=pyh9f0ad1d_0
#   - ca-certificates=2020.6.20=hecda079_0
#   - certifi=2020.6.20=py38h32f6830_0
#   - cffi=1.14.1=py38he30daa8_0
#   - decorator=4.4.2=py_0
#   - defusedxml=0.6.0=py_0
#   - entrypoints=0.3=py38h32f6830_1001
#   - importlib-metadata=1.7.0=py38h32f6830_0
#   - importlib_metadata=1.7.0=0
#   - ipykernel=5.3.4=py38h23f93f0_0
#   - ipython=7.17.0=py38h1cdfbd6_0
#   - ipython_genutils=0.2.0=py_1
#   - jedi=0.15.2=py38_0
#   - jinja2=2.11.2=pyh9f0ad1d_0
#   - jsonschema=3.2.0=py38h32f6830_1
#   - jupyter_client=6.1.6=py_0
#   - jupyter_core=4.6.3=py38h32f6830_1
#   - ld_impl_linux-64=2.33.1=h53a641e_7
#   - libedit=3.1.20191231=h14c3975_1
#   - libffi=3.3=he6710b0_2
#   - libgcc-ng=9.1.0=hdf63c60_0
#   - libsodium=1.0.18=h516909a_0
#   - libstdcxx-ng=9.1.0=hdf63c60_0
#   - markupsafe=1.1.1=py38h1e0a361_1
#   - mistune=0.8.4=py38h1e0a361_1001
#   - nbconvert=5.6.1=py38h32f6830_1
#   - nbformat=5.0.7=py_0
#   - ncurses=6.2=he6710b0_1
#   - notebook=6.1.3=py38h32f6830_0
#   - openssl=1.1.1g=h516909a_1
#   - packaging=20.4=pyh9f0ad1d_0
#   - pandoc=2.10.1=h516909a_0
#   - pandocfilters=1.4.2=py_1
#   - parso=0.8.0=pyh9f0ad1d_0
#   - pexpect=4.8.0=py38h32f6830_1
#   - pickleshare=0.7.5=py38h32f6830_1001
#   - pip=20.2.2=py38_0
#   - prometheus_client=0.8.0=pyh9f0ad1d_0
#   - prompt-toolkit=3.0.6=py_0
#   - ptyprocess=0.6.0=py_1001
#   - pycparser=2.20=pyh9f0ad1d_2
#   - pygments=2.6.1=py_0
#   - pyparsing=2.4.7=pyh9f0ad1d_0
#   - pyrsistent=0.16.0=py38h1e0a361_0
#   - python=3.8.5=hcff3b4d_0
#   - python-dateutil=2.8.1=py_0
#   - python_abi=3.8=1_cp38
#   - pyzmq=19.0.2=py38ha71036d_0
#   - readline=8.0=h7b6447c_0
#   - send2trash=1.5.0=py_0
#   - setuptools=49.6.0=py38_0
#   - six=1.15.0=pyh9f0ad1d_0
#   - sqlite=3.32.3=h62c20be_0
#   - terminado=0.8.3=py38h32f6830_1
#   - testpath=0.4.4=py_0
#   - tk=8.6.10=hbc83047_0
#   - tornado=6.0.4=py38h1e0a361_1
#   - traitlets=4.3.3=py38h32f6830_1
#   - wcwidth=0.2.5=pyh9f0ad1d_1
#   - webencodings=0.5.1=py_1
#   - wheel=0.34.2=py38_0
#   - xz=5.2.5=h7b6447c_0
#   - zeromq=4.3.2=he1b5a44_3
#   - zipp=3.1.0=py_0
#   - zlib=1.2.11=h7b6447c_3
#   - pip:
#     - absl-py==0.9.0
#     - cachetools==4.1.1
#     - chardet==3.0.4
#     - cycler==0.10.0
#     - cython==0.29.21
#     - future==0.18.2
#     - google-auth==1.20.1
#     - google-auth-oauthlib==0.4.1
#     - grpcio==1.31.0
#     - idna==2.10
#     - kiwisolver==1.2.0
#     - markdown==3.2.2
#     - matplotlib==3.3.2
#     - numpy==1.19.2
#     - oauthlib==3.1.0
#     - opencv-python==4.4.0.44
#     - pillow==7.2.0
#     - protobuf==3.12.4
#     - pyasn1==0.4.8
#     - pyasn1-modules==0.2.8
#     - pyyaml==5.3.1
#     - requests==2.24.0
#     - requests-oauthlib==1.3.0
#     - rsa==4.6
#     - scipy==1.5.2
#     - tensorboard==2.3.0
#     - tensorboard-plugin-wit==1.7.0
#     - torch==1.6.0+cu101
#     - torchvision==0.7.0+cu101
#     - tqdm==4.50.2
#     - urllib3==1.25.10
#     - werkzeug==1.0.1
# prefix: /home/yuri/anaconda3/envs/yv5

# %% [markdown]
# ## Especificações do Computador e do Experimento

# %%
# Especificações do computador, para saber onde estou rodando o código...
import datetime
from platform import uname
from os import environ
from glob import glob
import cv2

start_time = datetime.datetime.now()
time_stamp = start_time.strftime("%d_%B_%Y_%Hh_%Mm_%Ss")

username = environ['USER']
sysinfo = uname()
hostname = sysinfo.node

root = "~/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1"

dropbox_dir = "~/Dropbox"

experimento = "YOLOv5_UAVDT_1"

output_dir = "%s/YoloV5_Runs/Experimentos/%s_%s"%(dropbox_dir,experimento,time_stamp)


# Checar conda environment
conda_env = !printenv CONDA_PROMPT_MODIFIER
if conda_env != ['(yv5) ']:
    raise SystemExit("ERRO.. Conda environment incorreto.")

# %%
print("""
==Computer Specifications==
username: {username}

hostname: {hostname}

system info: {sysinfo}

{{root}}: {root}

dropbox dir: {dropbox_dir}

experimento: {experimento}

time stamp: {time_stamp}

output dir: {output_dir}
===========================
""".format(username = username, hostname = hostname, sysinfo = sysinfo,
           conda_env = conda_env, root = root, dropbox_dir = dropbox_dir,
           time_stamp = time_stamp, experimento = experimento, output_dir = output_dir))
# Out:
# ==Computer Specifications==
# username: yuri
#
# hostname: febe
#
# system info: uname_result(system='Linux', node='febe', release='4.15.0-117-generic', version='#118~16.04.1-Ubuntu SMP Sat Sep 5 23:35:06 UTC 2020', machine='x86_64', processor='x86_64')
#
# {root}: ~/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1
#
# dropbox dir: ~/Dropbox
#
# experimento: YOLOv5_UAVDT_1
#
# time stamp: 09_October_2020_15h_11m_56s
#
# output dir: ~/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s
# ===========================

# %%
# !nvidia-smi
# Out:
# Fri Oct  9 15:11:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 418.56       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 16%   57C    P2    62W / 280W |  10763MiB / 11178MiB |     16%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 22%   60C    P0    58W / 280W |      0MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  Off  | 00000000:03:00.0 Off |                  N/A |
# | 17%   59C    P0    57W / 280W |      0MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  Off  | 00000000:04:00.0 Off |                  N/A |
# |  9%   58C    P0    57W / 280W |      0MiB / 11177MiB |      6%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     13629      C   python3                                    10753MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Clonar o Repositório YOLOv5 e instalar os requirements.txt

# %%
#Ir para a raiz
# %cd {root}
# !echo
# Remover diretórios antigos
# !rm -rf runs yolov5
#Criar pasta de runs
# !mkdir runs
# !echo
#Copiar diretório novo da pasta submodules
# !cp -av ../../Submodules/yolov5/ yolov5/
# !echo
# !ls
#Entrar na pasta yolov5 e instalar os requirements.txt
# %cd {root}/yolov5/
# %pip install -U -r requirements.txt
# Out:
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1
#
#
# '../../Submodules/yolov5/' -> 'yolov5/'
# '../../Submodules/yolov5/Dockerfile' -> 'yolov5/Dockerfile'
# '../../Submodules/yolov5/README.md' -> 'yolov5/README.md'
# '../../Submodules/yolov5/detect.py' -> 'yolov5/detect.py'
# '../../Submodules/yolov5/hubconf.py' -> 'yolov5/hubconf.py'
# '../../Submodules/yolov5/.git' -> 'yolov5/.git'
# '../../Submodules/yolov5/.dockerignore' -> 'yolov5/.dockerignore'
# '../../Submodules/yolov5/.gitattributes' -> 'yolov5/.gitattributes'
# '../../Submodules/yolov5/.gitignore' -> 'yolov5/.gitignore'
# '../../Submodules/yolov5/requirements.txt' -> 'yolov5/requirements.txt'
# '../../Submodules/yolov5/LICENSE' -> 'yolov5/LICENSE'
# '../../Submodules/yolov5/test.py' -> 'yolov5/test.py'
# '../../Submodules/yolov5/train.py' -> 'yolov5/train.py'
# '../../Submodules/yolov5/tutorial.ipynb' -> 'yolov5/tutorial.ipynb'
# '../../Submodules/yolov5/.github' -> 'yolov5/.github'
# '../../Submodules/yolov5/.github/ISSUE_TEMPLATE' -> 'yolov5/.github/ISSUE_TEMPLATE'
# '../../Submodules/yolov5/.github/ISSUE_TEMPLATE/--bug-report.md' -> 'yolov5/.github/ISSUE_TEMPLATE/--bug-report.md'
# '../../Submodules/yolov5/.github/ISSUE_TEMPLATE/--feature-request.md' -> 'yolov5/.github/ISSUE_TEMPLATE/--feature-request.md'
# '../../Submodules/yolov5/.github/ISSUE_TEMPLATE/-question.md' -> 'yolov5/.github/ISSUE_TEMPLATE/-question.md'
# '../../Submodules/yolov5/.github/workflows' -> 'yolov5/.github/workflows'
# '../../Submodules/yolov5/.github/workflows/ci-testing.yml' -> 'yolov5/.github/workflows/ci-testing.yml'
# '../../Submodules/yolov5/.github/workflows/greetings.yml' -> 'yolov5/.github/workflows/greetings.yml'
# '../../Submodules/yolov5/.github/workflows/stale.yml' -> 'yolov5/.github/workflows/stale.yml'
# '../../Submodules/yolov5/.github/workflows/rebase.yml' -> 'yolov5/.github/workflows/rebase.yml'
# '../../Submodules/yolov5/data' -> 'yolov5/data'
# '../../Submodules/yolov5/data/coco.yaml' -> 'yolov5/data/coco.yaml'
# '../../Submodules/yolov5/data/coco128.yaml' -> 'yolov5/data/coco128.yaml'
# '../../Submodules/yolov5/data/hyp.finetune.yaml' -> 'yolov5/data/hyp.finetune.yaml'
# '../../Submodules/yolov5/data/voc.yaml' -> 'yolov5/data/voc.yaml'
# '../../Submodules/yolov5/data/hyp.scratch.yaml' -> 'yolov5/data/hyp.scratch.yaml'
# '../../Submodules/yolov5/data/scripts' -> 'yolov5/data/scripts'
# '../../Submodules/yolov5/data/scripts/get_coco.sh' -> 'yolov5/data/scripts/get_coco.sh'
# '../../Submodules/yolov5/data/scripts/get_voc.sh' -> 'yolov5/data/scripts/get_voc.sh'
# '../../Submodules/yolov5/inference' -> 'yolov5/inference'
# '../../Submodules/yolov5/inference/images' -> 'yolov5/inference/images'
# '../../Submodules/yolov5/inference/images/bus.jpg' -> 'yolov5/inference/images/bus.jpg'
# '../../Submodules/yolov5/inference/images/zidane.jpg' -> 'yolov5/inference/images/zidane.jpg'
# '../../Submodules/yolov5/models' -> 'yolov5/models'
# '../../Submodules/yolov5/models/common.py' -> 'yolov5/models/common.py'
# '../../Submodules/yolov5/models/experimental.py' -> 'yolov5/models/experimental.py'
# '../../Submodules/yolov5/models/export.py' -> 'yolov5/models/export.py'
# '../../Submodules/yolov5/models/yolo.py' -> 'yolov5/models/yolo.py'
# '../../Submodules/yolov5/models/yolov5l.yaml' -> 'yolov5/models/yolov5l.yaml'
# '../../Submodules/yolov5/models/yolov5m.yaml' -> 'yolov5/models/yolov5m.yaml'
# '../../Submodules/yolov5/models/yolov5s.yaml' -> 'yolov5/models/yolov5s.yaml'
# '../../Submodules/yolov5/models/yolov5x.yaml' -> 'yolov5/models/yolov5x.yaml'
# '../../Submodules/yolov5/models/__init__.py' -> 'yolov5/models/__init__.py'
# '../../Submodules/yolov5/models/hub' -> 'yolov5/models/hub'
# '../../Submodules/yolov5/models/hub/yolov3-spp.yaml' -> 'yolov5/models/hub/yolov3-spp.yaml'
# '../../Submodules/yolov5/models/hub/yolov5-fpn.yaml' -> 'yolov5/models/hub/yolov5-fpn.yaml'
# '../../Submodules/yolov5/models/hub/yolov5-panet.yaml' -> 'yolov5/models/hub/yolov5-panet.yaml'
# '../../Submodules/yolov5/utils' -> 'yolov5/utils'
# '../../Submodules/yolov5/utils/activations.py' -> 'yolov5/utils/activations.py'
# '../../Submodules/yolov5/utils/datasets.py' -> 'yolov5/utils/datasets.py'
# '../../Submodules/yolov5/utils/torch_utils.py' -> 'yolov5/utils/torch_utils.py'
# '../../Submodules/yolov5/utils/__init__.py' -> 'yolov5/utils/__init__.py'
# '../../Submodules/yolov5/utils/google_utils.py' -> 'yolov5/utils/google_utils.py'
# '../../Submodules/yolov5/utils/general.py' -> 'yolov5/utils/general.py'
# '../../Submodules/yolov5/weights' -> 'yolov5/weights'
# '../../Submodules/yolov5/weights/download_weights.sh' -> 'yolov5/weights/download_weights.sh'
#
# Resultados.ipynb  YOLOv5_UAVDT_1_TRAIN.ipynb  logs  runs  yolov5
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1/yolov5
# Requirement already up-to-date: Cython in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.29.21)
# Requirement already up-to-date: matplotlib>=3.2.2 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (3.3.2)
# Requirement already up-to-date: numpy>=1.18.5 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (1.19.2)
# Requirement already up-to-date: opencv-python>=4.1.2 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (4.4.0.44)
# Requirement already up-to-date: pillow in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (7.2.0)
# Requirement already up-to-date: PyYAML>=5.3 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (5.3.1)
# Requirement already up-to-date: scipy>=1.4.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.5.2)
# Requirement already up-to-date: tensorboard>=2.2 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (2.3.0)
# Requirement already up-to-date: torch>=1.6.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (1.6.0+cu101)
# Requirement already up-to-date: torchvision>=0.7.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.7.0+cu101)
# Requirement already up-to-date: tqdm>=4.41.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (4.50.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (1.20.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (0.34.2)
# Requirement already satisfied, skipping upgrade: grpcio>=1.24.3 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (1.31.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (2.24.0)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (1.7.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (49.6.0.post20200814)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (3.2.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (3.12.4)
# Requirement already satisfied, skipping upgrade: absl-py>=0.4 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from tensorboard>=2.2->-r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied, skipping upgrade: future in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from torch>=1.6.0->-r requirements.txt (line 12)) (0.18.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2->-r requirements.txt (line 11)) (4.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2->-r requirements.txt (line 11)) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2->-r requirements.txt (line 11)) (4.6)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2->-r requirements.txt (line 11)) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2->-r requirements.txt (line 11)) (1.25.10)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2->-r requirements.txt (line 11)) (2.10)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2->-r requirements.txt (line 11)) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /home/yuri/anaconda3/envs/yv5/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2->-r requirements.txt (line 11)) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Executar Script para Transformar Imagens do UAVDT Dataset para o formato requerido pelo YOLOv5

# %%
# Ir para a raiz
# %cd {root}
# Out:
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1

# %%
# %%script bash
# # Apagar os links existentes para o dataset
# rm -rfv UAVDT_YOLOv5
# # Criar novos hard links para o dataset e organizer o dataset no formato exigido pelo yolov5
# mkdir UAVDT_YOLOv5
# # Executar o script para converter UAVDT para o formato YOLOv5:
# cd ../../misc
#
# python uavdt_to_yolov5.py --conjunto treinoEteste --dest ../RedesNeurais/YOLOv5_UAVDT_1/UAVDT_YOLOv5 --nosymlink
#
# cd ../RedesNeurais/YOLOv5_UAVDT_1/
# Out:
# [INFO] Etiqueta de Tempo: 09_10_2020_15_12_02.
# [INFO] Iniciando processo de transformação para Treino.
# [INFO] Analisando imagens do clipe: M0101...
# [INFO] Analisando imagens do clipe: M0201...
# [INFO] Analisando imagens do clipe: M0202...
# [INFO] Analisando imagens do clipe: M0204...
# [INFO] Analisando imagens do clipe: M0206...
# [INFO] Analisando imagens do clipe: M0207...
# [INFO] Analisando imagens do clipe: M0210...
# [INFO] Analisando imagens do clipe: M0301...
# [INFO] Analisando imagens do clipe: M0401...
# [INFO] Analisando imagens do clipe: M0402...
# [INFO] Analisando imagens do clipe: M0501...
# [INFO] Analisando imagens do clipe: M0603...
# [INFO] Analisando imagens do clipe: M0604...
# [INFO] Analisando imagens do clipe: M0605...
# [INFO] Analisando imagens do clipe: M0702...
# [INFO] Analisando imagens do clipe: M0703...
# [INFO] Analisando imagens do clipe: M0704...
# [INFO] Analisando imagens do clipe: M0901...
# [INFO] Analisando imagens do clipe: M0902...
# [INFO] Analisando imagens do clipe: M1002...
# [INFO] Analisando imagens do clipe: M1003...
# [INFO] Analisando imagens do clipe: M1005...
# [INFO] Analisando imagens do clipe: M1006...
# [INFO] Analisando imagens do clipe: M1008...
# [INFO] Analisando imagens do clipe: M1102...
# [INFO] Analisando imagens do clipe: M1201...
# [INFO] Analisando imagens do clipe: M1202...
# [INFO] Analisando imagens do clipe: M1304...
# [INFO] Analisando imagens do clipe: M1305...
# [INFO] Analisando imagens do clipe: M1306...
# [INFO] Processo finalizado para o conjunto de Treino.
#  Total de Imagens Analisadas: 24143. Total de Imagens Transformadas: 23860. Total de Imagens Sem Labels: 283.
# [INFO] Iniciando processo de transformação para Teste.
# [INFO] Analisando imagens do clipe: M0203...
# [INFO] Analisando imagens do clipe: M0205...
# [INFO] Analisando imagens do clipe: M0208...
# [INFO] Analisando imagens do clipe: M0209...
# [INFO] Analisando imagens do clipe: M0403...
# [INFO] Analisando imagens do clipe: M0601...
# [INFO] Analisando imagens do clipe: M0602...
# [INFO] Analisando imagens do clipe: M0606...
# [INFO] Analisando imagens do clipe: M0701...
# [INFO] Analisando imagens do clipe: M0801...
# [INFO] Analisando imagens do clipe: M0802...
# [INFO] Analisando imagens do clipe: M1001...
# [INFO] Analisando imagens do clipe: M1004...
# [INFO] Analisando imagens do clipe: M1007...
# [INFO] Analisando imagens do clipe: M1009...
# [INFO] Analisando imagens do clipe: M1101...
# [INFO] Analisando imagens do clipe: M1301...
# [INFO] Analisando imagens do clipe: M1302...
# [INFO] Analisando imagens do clipe: M1303...
# [INFO] Analisando imagens do clipe: M1401...
# [INFO] Processo finalizado para o conjunto de Teste.
#  Total de Imagens Analisadas: 16592. Total de Imagens Transformadas: 16581. Total de Imagens Sem Labels: 11.

# %% [markdown]
# # Preprocessar as imagens
# ## Salvá-las temporariamente (enquanto estiver treinando a rede). Após o término do treinamento, deve-se apagar as imagens objetivando economizar espaço em disco.

# %%
movies_treino = ["M0101", "M0201", "M0202", "M0204", \
    "M0206", "M0207", "M0210", "M0301", "M0401", "M0402", \
    "M0501", "M0603","M0604", "M0605", "M0702", "M0703", \
    "M0704", "M0901", "M0902", "M1002", "M1003", "M1005", \
    "M1006", "M1008", "M1102", "M1201", "M1202", "M1304", \
    "M1305", "M1306"]

for movie_name in movies_treino:
    print(f"[INFO] Analisando a sequência de imagens {movie_name}.")

    frame_boxes = {}
    with open(f"../../Datasets/UAVDT/UAV-benchmark-MOTD_v1.0/GT/{movie_name}_gt_ignore.txt") as igfile:
        lines = igfile.readlines()
        for line in lines:
            line = line.split(",")
            frame = int(line[0])
            x = int(line[2])
            y = int(line[3])
            w = int(line[4])
            h = int(line[5])
            classe = int(line[-1])
            if frame in frame_boxes:
                frame_boxes[frame] += [[frame, x, y, w, h, classe]]
            else:
                frame_boxes[frame] = [[frame, x, y, w, h, classe]]

    # Para cada vídeo, ajustar as imagens do UAVDT Local com os devidos blurs..
    for frame, boxes in frame_boxes.items():
        img_path = f"./UAVDT_YOLOv5/train/images/{movie_name}_img{frame:06}.jpg"
        img = cv2.imread(img_path)
        for _,x,y,w,h,_ in boxes:
            # Kernel Sized
            kw = w//2
            kh = h//2
            if kw % 2 == 0: kw -= 1
            if kh % 2 == 0: kh -= 1
            # Gaussian Blur
            roi = img[y:y+h, x:x+w]
            roi_blur = cv2.GaussianBlur(roi, (kw, kh), 20, 20, cv2.BORDER_REPLICATE)
            img[y:y+h, x:x+w] = roi_blur
        
        cv2.imwrite(img_path, img)

"""
# Checar efeitos do Gaussian Blur em uma "ignore area" de uma imagem qualquer do dataset.

img = cv2.imread("../../Datasets/UAVDT/UAV-benchmark-M/M0101/img000001.jpg")
# Boxes da imagem 000001.jpg do filme M0101; [frame, x, y, w, h, classe]
frame1_boxes_img000001_M0101 = [[1, 914, 189, 105, 54, -1],  [1, 956, 480, 64, 58, -1],  [1, 788, 291, 121, 113, -1]]

for _,x,y,w,h,_ in frame1_boxes_img000001_M0101:
    # Kernel Sized
    kw = w//2
    kh = h//2
    if kw % 2 == 0: kw -= 1
    if kh % 2 == 0: kh -= 1
    # 2xGaussian Blur
    roi = img[y:y+h, x:x+w]
    roi_blur = cv2.GaussianBlur(roi, (kw, kh), 20, 20, cv2.BORDER_REPLICATE)
    img[y:y+h, x:x+w] = roi_blur

cv2.imshow("Teste", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
"""
pass
# Out:
# [INFO] Analisando a sequência de imagens M0101.
# [INFO] Analisando a sequência de imagens M0201.
# [INFO] Analisando a sequência de imagens M0202.
# [INFO] Analisando a sequência de imagens M0204.
# [INFO] Analisando a sequência de imagens M0206.
# [INFO] Analisando a sequência de imagens M0207.
# [INFO] Analisando a sequência de imagens M0210.
# [INFO] Analisando a sequência de imagens M0301.
# [INFO] Analisando a sequência de imagens M0401.
# [INFO] Analisando a sequência de imagens M0402.
# [INFO] Analisando a sequência de imagens M0501.
# [INFO] Analisando a sequência de imagens M0603.
# [INFO] Analisando a sequência de imagens M0604.
# [INFO] Analisando a sequência de imagens M0605.
# [INFO] Analisando a sequência de imagens M0702.
# [INFO] Analisando a sequência de imagens M0703.
# [INFO] Analisando a sequência de imagens M0704.
# [INFO] Analisando a sequência de imagens M0901.
# [INFO] Analisando a sequência de imagens M0902.
# [INFO] Analisando a sequência de imagens M1002.
# [INFO] Analisando a sequência de imagens M1003.
# [INFO] Analisando a sequência de imagens M1005.
# [INFO] Analisando a sequência de imagens M1006.
# [INFO] Analisando a sequência de imagens M1008.
# [INFO] Analisando a sequência de imagens M1102.
# [INFO] Analisando a sequência de imagens M1201.
# [INFO] Analisando a sequência de imagens M1202.
# [INFO] Analisando a sequência de imagens M1304.
# [INFO] Analisando a sequência de imagens M1305.
# [INFO] Analisando a sequência de imagens M1306.

# %% [markdown]
# # Criar o arquivo data.yaml

# %%
# O conteúdo original não está adequado... mais fácil que editar: removerei-o e criarei um novo.
# %cd {root}

datayaml = """# train and val datasets (image directory or *.txt file with image paths)

train: ../UAVDT_YOLOv5/train/images/
val: ../UAVDT_YOLOv5/test/images/

# number of classes
nc: 3

# class names
names: ['car', 'truck', 'bus']
"""

# %rm data.yaml
with open('data.yaml', 'w') as file:
    file.write(datayaml)
# %cat data.yaml
# Out:
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1
# rm: cannot remove 'data.yaml': No such file or directory
# # train and val datasets (image directory or *.txt file with image paths)
#
# train: ../UAVDT_YOLOv5/train/images/
# val: ../UAVDT_YOLOv5/test/images/
#
# # number of classes
# nc: 3
#
# # class names
# names: ['car', 'truck', 'bus']

# %% [markdown]
# # Iniciar o Treinamento por 300 eṕocas

# %%
# %cd {root}/yolov5
epocas = 300

# !python train.py --epochs {epocas} --cfg ./models/yolov5l.yaml --weights ../../../Weights/YoloV5/yolov5l.pt  --data ../data.yaml --img 640 --batch-size 16 --device 1 --logdir ../runs --workers 4
# Out:
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1/yolov5
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11178MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='./models/yolov5l.yaml', data='../data.yaml', device='1', epochs=300, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[640, 640], local_rank=-1, logdir='../runs', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=16, weights='../../../Weights/YoloV5/yolov5l.pt', workers=4, world_size=1)
# Start Tensorboard with "tensorboard --logdir ../runs", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mixup': 0.0}
# Overriding ./models/yolov5l.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1627904  models.common.BottleneckCSP             [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6499840  models.common.BottleneckCSP             [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1  10234880  models.common.BottleneckCSP             [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2823680  models.common.BottleneckCSP             [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    707328  models.common.BottleneckCSP             [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2561536  models.common.BottleneckCSP             [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1  10234880  models.common.BottleneckCSP             [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     43080  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 335 layers, 4.74041e+07 parameters, 4.74041e+07 gradients
#
# Transferred 650/658 items from ../../../Weights/YoloV5/yolov5l.pt
# Optimizer groups: 110 .bias, 118 conv.weight, 107 other
# Scanning images: 100%|██████████████████| 23860/23860 [00:04<00:00, 5183.54it/s]
# Scanning labels ../UAVDT_YOLOv5/train/labels.cache (23860 found, 0 missing, 0 empty, 0 duplicate, for 23860 images): 23860it [00:02, 11474.00it/s]
# Scanning images: 100%|██████████████████| 16581/16581 [00:02<00:00, 6510.76it/s]
# Scanning labels ../UAVDT_YOLOv5/test/labels.cache (16581 found, 0 missing, 0 empty, 1 duplicate, for 16581 images): 16581it [00:01, 11454.87it/s]
#
# Analyzing anchors... anchors/target = 4.35, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 4 dataloader workers
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/299     9.17G   0.06082   0.08902   0.01151    0.1613       136       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.234       0.468       0.258       0.135
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/299     9.19G   0.04607   0.08028  0.004212    0.1306        71       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.256       0.439       0.249       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/299     9.19G   0.04324   0.07822  0.003266    0.1247       221       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.214       0.414       0.215       0.118
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/299     9.19G   0.03988   0.07556  0.002792    0.1182       123       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.265       0.396       0.231        0.13
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/299     9.19G   0.03725   0.07347  0.002345    0.1131       143       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.257       0.407       0.256       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/299     9.19G   0.03613   0.07235  0.002134    0.1106        87       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.279       0.324       0.217       0.126
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/299     9.19G   0.03518   0.07189  0.001956     0.109       130       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.278       0.368       0.243        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/299     9.19G   0.03473   0.07152  0.001873    0.1081       155       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.275       0.356       0.237       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/299     9.19G   0.03392   0.07077  0.001799    0.1065       213       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.306       0.359       0.245       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/299     9.19G   0.03333   0.06964  0.001737    0.1047       101       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05        0.25       0.307       0.211       0.118
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/299     9.19G   0.03292   0.06948  0.001667    0.1041       146       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.296       0.352        0.24       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/299     9.19G    0.0327   0.06921  0.001658    0.1036       204       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.242       0.322       0.211       0.118
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/299     9.19G   0.03226    0.0691  0.001548    0.1029       108       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0
640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.283       0.273       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    270/299     9.19G   0.02126   0.05834 0.0008032   0.08041        98       640
#    271/299     9.19G   0.02131     0.058 0.0008279   0.08013        97       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.286       0.274       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    272/299     9.19G   0.02156   0.05876  0.000842   0.08116       164       640
#    273/299     9.19G   0.02134    0.0585 0.0008062   0.08065       182       640
#    274/299     9.19G   0.02138   0.05786 0.0008123   0.08005       115       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.274       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.274       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.288       0.274       0.199       0.111
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    278/299     9.19G   0.02135   0.05838 0.0008234   0.08056       171       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.289       0.274       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    279/299     9.19G   0.02121   0.05795 0.0008176   0.07997       167       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.288       0.274       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    281/299     9.19G   0.02129   0.05814 0.0008236   0.08025        68       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.288       0.272       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.288       0.272       0.198        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    284/299     9.19G   0.02126   0.05767 0.0008025   0.07973        76       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.272       0.197        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.272       0.197        0.11
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.271       0.197       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    290/299     9.19G   0.02103   0.05764 0.0008156   0.07949       169       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.287       0.271       0.197       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    292/299     9.19G   0.02168   0.05867 0.0008225   0.08117        88       640
#    293/299     9.19G   0.02119   0.05759 0.0007959   0.07957       199       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.286        0.27       0.197       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.286        0.27       0.196       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    296/299     9.19G   0.02117   0.05818 0.0008104   0.08016       174       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.285       0.269       0.196       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.285       0.269       0.196       0.109
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    299/299     9.19G   0.02116   0.05794 0.0008002    0.0799       166       640
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.66e+04    3.74e+05       0.285       0.269       0.196       0.109
# Optimizer stripped from ../runs/exp0/weights/last.pt, 95.3MB
# Optimizer stripped from ../runs/exp0/weights/best.pt, 95.3MB
# 300 epochs completed in 183.865 hours.

# %% [markdown]
# # Guardar os Resultados na Nuvem (Dropbox)

# %%
# %cd {root}
# %mkdir -p {output_dir}
# %cp -av logs/ {output_dir}
# %cp -av runs/ {output_dir}
# Out:
# /home/yuri/Desktop/Mestrado/Codigos_Dissertacao/RedesNeurais/YOLOv5_UAVDT_1
# 'logs/' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/logs'
# 'logs/YOLOv5_UAVDT_1_TRAIN_ipynb_09_October_2020_15h_11m_52s.txt' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/logs/YOLOv5_UAVDT_1_TRAIN_ipynb_09_October_2020_15h_11m_52s.txt'
# 'runs/' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs'
# 'runs/exp0' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0'
# 'runs/exp0/events.out.tfevents.1602268152.febe.16062.0' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/events.out.tfevents.1602268152.febe.16062.0'
# 'runs/exp0/hyp.yaml' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/hyp.yaml'
# 'runs/exp0/opt.yaml' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/opt.yaml'
# 'runs/exp0/labels.png' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/labels.png'
# 'runs/exp0/train_batch0.jpg' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/train_batch0.jpg'
# 'runs/exp0/train_batch1.jpg' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/train_batch1.jpg'
# 'runs/exp0/train_batch2.jpg' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/train_batch2.jpg'
# 'runs/exp0/test_batch0_gt.jpg' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/test_batch0_gt.jpg'
# 'runs/exp0/test_batch0_pred.jpg' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/test_batch0_pred.jpg'
# 'runs/exp0/results.txt' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/results.txt'
# 'runs/exp0/weights' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/weights'
# 'runs/exp0/weights/last.pt' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/weights/last.pt'
# 'runs/exp0/weights/best.pt' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/weights/best.pt'
# 'runs/exp0/results.png' -> '/home/yuri/Dropbox/YoloV5_Runs/Experimentos/YOLOv5_UAVDT_1_09_October_2020_15h_11m_56s/runs/exp0/results.png'

# %% [markdown]
# # Finalização

# %%
finish_time = datetime.datetime.now()
delta_time = finish_time - start_time
print("""
Start: {start}

Finish: {finish}

Duration (hour:min:sec.microsec):  {delta}
""".format(start = start_time, finish = finish_time, delta = delta_time))
# Out:
# Start: 2020-10-09 15:11:56.165383
#
# Finish: 2020-10-17 07:22:03.133650
#
# Duration (hour:min:sec.microsec):  7 days, 16:10:06.968267

# %%
# Manualmente, remover os logs e diretórios com imagens desnecessários.
